# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 50px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 2;
#     border-radius: 30px;
#     margin: 20px 0;
# ">
#     <b>📈 Exploring Salary Trends in Data Science Careers</b>
# </div>
#
# <div align="center" style="margin-top: 20px;">
#     <img src="https://www.doersempire.com/wp-content/uploads/2019/11/7-Reasons-most-businesses-dont-reach-6-figures-1280x640.jpg"
#          alt="Data Science Trends"
#          style="max-width: 100%; height: auto; border-radius: 15px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1);" />
# </div>

# %% [markdown]
# <div align="left" style="font-size:25px; font-weight:bold;">
#     👤 Yusuf Delikkaya
# </div>
#
# <br>
#
# <p align="left" style="font-size:18px; font-weight:bold;">
#     🚀 Discover My Projects and Stay Connected!
# </p>
#
# <p align="left" style="font-size:15px;">
# 🌍 If you're interested in my other projects, don't forget to follow me on these platforms:
# </p>
#
# <p align="left">
#     <a href="https://linktr.ee/yusufdelikkaya" target="_blank" style="text-decoration:none;">
#         <img src="https://img.shields.io/badge/Linktree-39E09B?style=for-the-badge&logo=linktree&logoColor=white" alt="Linktree" />
#     </a>
#     <a href="https://www.linkedin.com/in/yusufdelikkaya" target="_blank" style="text-decoration:none;">
#         <img src="https://img.shields.io/badge/LinkedIn-0A66C2?style=for-the-badge&logo=linkedin&logoColor=white" alt="LinkedIn" />
#     </a>
#     <a href="https://www.kaggle.com/yusufdelikkaya" target="_blank" style="text-decoration:none;">
#         <img src="https://img.shields.io/badge/Kaggle-20BEFF?style=for-the-badge&logo=kaggle&logoColor=white" alt="Kaggle" />
#     </a>
#     <a href="https://github.com/yusufdelikkaya" target="_blank" style="text-decoration:none;">
#         <img src="https://img.shields.io/badge/GitHub-181717?style=for-the-badge&logo=github&logoColor=white" alt="GitHub" />
#     </a>
#     <a href="https://public.tableau.com/app/profile/yusuf.delikkaya/vizzes" target="_blank" style="text-decoration:none;">
#         <img src="https://img.shields.io/badge/Tableau-E97627?style=for-the-badge&logo=tableau&logoColor=white" alt="Tableau" />
#     </a>
# </p>

# %% [markdown]
# ## **Exploring Salary Trends in Data Science Careers**
#
# - Welcome to the Exploring Salary Trends in Data Science Careers project!
#
# - In this analysis, we delve into the world of data science jobs to gain insights into the factors that influence employment in this field.
#
# - Whether you're a seasoned data scientist looking to benchmark your earnings or someone considering a career in data science, this analysis aims to provide valuable insights into employment trends.
#
# ### **Dataset**
#
# - The dataset used in this analysis comprises anonymized data on jobs in data science collected from various sources, including surveys, job postings, and public records.
#
# - This dataset can be utilized for analyzing salary trends and variations in data science jobs over time and across different demographics.
#
# - It can aid in benchmarking salaries, understanding the impact of factors such as experience level and company size on compensation, and informing career decisions in the data science field.
#
# ### **Column Description**
#
# | Column Name         | Description                                                           |
# |---------------------|-----------------------------------------------------------------------|
# | work_year           | The year the data related to the job salary was collected.            |
# | experience_level    | The employee's experience level (e.g., Junior, Mid-Level).            |
# | employment_type     | The type of employment (e.g., Full-Time, Part-Time).                  |
# | job_title           | The employee's title or role within the data science field.           |
# | salary              | The employee's salary.                                                |
# | salary_currency     | The currency in which the salary is denoted.                          |
# | salary_in_usd       | The salary converted to US dollars for standardization.               |
# | employee_residence  | The employee's residence location.                                    |
# | remote_ratio        | The ratio of remote work allowed for the position.                    |
# | company_location    | The location of the company.                                          |
# | company_size        | The size of the company based on employee count or revenue.           |
#
# <br/>
#
# ### **Analysis Overview**
#
# - This notebook provides a structured approach to handling data cleaning, exploratory data analysis (EDA), and data visualization tasks using the provided dataset.
#
# - Each step will cover various aspects of cleaning, analyzing, and visualizing the dataset.
#
# - Our analysis will be divided into several key sections:
#
# <br/>
#
# | Step                | Analysis                                    |
# |---------------------|---------------------------------------------|
# | **Step 1:**         | Import Libraries, Loading the Dataset       |
# | **Step 2:**         | Initial Exploration and Analyzing Values    |
# | **Step 3:**         | Organizing & Manipulating Data              |
# | **Step 4:**         | Detecting and Handling Outliers             |
# | **Step 5:**         | Data Visualization                          |
# | **Step 6:**         | Conclusion - Key Insights and Summary       |

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 1: Import Libraries, Loading the Dataset</b>
# </div>

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>1.1. Import Libraries & Configure Settings</b>
# </div>

# %%
# Import Libraries & Configure Settings

# Install
# !pip install skimpy

# Data Visualization Libraries
import numpy as np  # Used for numerical computations and data manipulation.
import pandas as pd  # Used for data analysis and handling data structures (DataFrame, Series).
import matplotlib as mpl
import matplotlib.pyplot as plt  # Core library for 2D plotting and data visualization.
from matplotlib.patches import FancyBboxPatch  # Used for drawing box visuals.
import seaborn as sns  # Used for statistical data visualization, built on top of Matplotlib.
import plotly.express as px  # Used for interactive charts and data visualization.
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
from skimpy import skim  # Used for quick summarization and inspection of data.
import statsmodels.api as sm  # Used for statistical analysis and modeling.
from wordcloud import WordCloud  # Used for creating word clouds.
import nltk  # Natural Language Toolkit: Used when creating word clouds.
from sklearn.preprocessing import LabelEncoder  # Used when creating HeatMaps.
import plotly.io as pio
pio.renderers.default = 'colab'
import os

# Styling & Settings
# %matplotlib inline 
# Ensures Matplotlib charts are displayed directly within the notebook cell.
sns.set_theme(style="dark")
plt.style.use('dark_background')

# Modify Pandas display settings:
pd.set_option('display.float_format', '{:.0f}'.format)  # Sets the decimal precision for numbers.
pd.set_option('display.max_columns', None)  # Ensures all columns are displayed.
pd.set_option('display.max_rows', None)  # Ensures all rows are displayed.

# Warnings Setting
import warnings  # Used to control and manage warning messages.
warnings.filterwarnings("ignore")  # Suppresses warning messages.
warnings.warn("this will not show")  # Example warning message, but it will be suppressed by ignore.

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>1.2. Loading & Reading Dataset</b>
# </div>

# %%
# Loading & Reading Dataset
df = pd.read_csv('DataScience_salaries_2024.csv')

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>1.3. Data Sample</b>
# </div>

# %%
# Data Sample
df.sample(10)
# Out:
#        work_year experience_level employment_type  \
# 6490        2023               SE              FT
# 1412        2023               SE              FT
# 14286       2022               MI              FT
# 11806       2023               SE              FT
# 9684        2023               MI              FT
# 11167       2023               SE              FT
# 5740        2023               SE              FT
# 2666        2022               SE              FT
# 10078       2024               MI              FT
# 10479       2023               SE              FT
#
#                                   job_title  salary salary_currency  \
# 6490                          Data Engineer  150600             USD
# 1412                          Data Engineer  240500             USD
# 14286                          Data Analyst   50000             GBP
# 11806                          Data Analyst   94000             USD
# 9684                          Data Engineer  120000             GBP
# ...

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 2: Initial Exploration and Analyzing Values</b>
# </div>

# %%
# Dataset Inıtial Summary by Skimpy Library
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 14838  │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 11     │ │ int32       │ 4     │                                                          │
# │ └───────────────────┴────────┘ └─────────────┴───────┘                                                          │
# ...

# %%
# Viewing Null, Unique and Duplicated Values

pd.DataFrame({
                'Count':df.shape[0],
                'Null':df.isnull().sum(),
                'Null %':df.isnull().mean() * 100,
                'Unique':df.nunique(),
                'Duplicated':(df.duplicated() == True).sum()
})
# Out:
#                     Count  Null  Null %  Unique  Duplicated
# work_year           14838     0       0       5        5711
# experience_level    14838     0       0       4        5711
# employment_type     14838     0       0       4        5711
# job_title           14838     0       0     153        5711
# salary              14838     0       0    2363        5711
# salary_currency     14838     0       0      23        5711
# salary_in_usd       14838     0       0    2730        5711
# employee_residence  14838     0       0      88        5711
# remote_ratio        14838     0       0       3        5711
# company_location    14838     0       0      77        5711
# company_size        14838     0       0       3        5711

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 3: Organizing & Manipulating Data</b>
# </div>

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>3.1. Generating Job Category Labels</b>
# </div>

# %%
# Simplifies job titles to broader job category labels and creates an original column.

# Mapping job titles to job categories.
def map_job_title(df, original_column='job_title', new_column='job_category'):

    # Define the mapping dictionary
    job_title_mapping = {
        'data analyst': 'Data Analyst',
        'bi analyst': 'Data Analyst',
        'analytics': 'Data Analyst',
        'data scientist': 'Data Scientist',
        'data science': 'Data Scientist',
        'decision scientist': 'Data Scientist',
        'data engineer': 'Data Engineer',
        'etl': 'Data Engineer',
        'pipeline': 'Data Engineer',
        'machine learning': 'ML Engineer',
        'ml': 'ML Engineer',
        'deep learning': 'ML Engineer',
        'ai': 'ML Engineer',
        'data architect': 'Data Engineer',
        'big data': 'Data Engineer',
        'cloud data': 'Data Engineer',
        'data manager': 'Data Engineer',
        'head of data': 'Data Engineer',
        'director': 'Data Engineer',
        'bi developer': 'Data Analyst',
        'power bi': 'Data Analyst',
        'business intelligence': 'Data Analyst',
        'research scientist': 'Data Scientist',
        'research engineer': 'Data Scientist',
        'statistician': 'Data Analyst',
        'quantitative': 'Data Analyst',
        'computational biologist': 'Data Scientist',
        'robotics': 'Data Engineer',
        'nlp': 'Data Engineer',
        'applied scientist': 'Data Scientist',
        'research analyst': 'Data Analyst',
        'data specialist ': 'Data Scientist',
        'data modeler': 'Data Engineer',
    }

    # Convert job titles to lowercase and map them to broader categories
    df[new_column] = df[original_column].str.lower().apply(
        lambda title: next((v for k, v in job_title_mapping.items() if k in title), 'Data Scientist')
    )
    return df

# Example usage
df = map_job_title(df)

# %%
# FancyBboxPatch: Visualization of the Generating Job Category Labels

# Define the job categories and their corresponding colors
job_categories = ['Data Scientist', 'Data Analyst', 'ML Engineer', 'Data Engineer']
colors = ['#6699CC', '#77B28C', '#C49C6B', '#C38F9E']

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))  # Slightly larger figure for better layout

# Draw rounded rectangles for each job category
for i, (category, color) in enumerate(zip(job_categories, colors)):
    row = i // 2  # Determine row (0 or 1)
    col = i % 2   # Determine column (0 or 1)

    # Create rounded rectangles using FancyBboxPatch
    rect = FancyBboxPatch(
        (col * 6, -row * 3), 5, 2,  # Position and size
        boxstyle="round,pad=0.3,rounding_size=0.3",  # Rounded corners
        color=color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect)

    # Add centered text inside each rectangle
    ax.text(
        col * 6 + 2.5, -row * 3 + 1, category,  # Adjusted text position
        va='center', ha='center', fontsize=20, color='white', weight='bold'
    )

# Adjust axis limits to fit all elements
ax.set_xlim(-1.5, 12.5)
ax.set_ylim(-5, 4)
ax.axis('off')  # Turn off the axis

# Optimize layout to avoid clipping
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>3.2. Generating Work Model Labels</b>
# </div>

# %%
# Converts remote ratio to work models labels and creates an original column.

# Mapping remote ratio to work models.
def map_remote_ratio(df, original_column='remote_ratio', new_column='work_model'):

    # Define the mapping dictionary
    remote_ratio_mapping = {
        0: 'In-Person',
        50: 'Hybrid',
        100: 'Remote'
    }

    # Apply the mapping with a default value of 'Other' for unmapped numbers
    df[new_column] = df[original_column].map(remote_ratio_mapping).fillna('Other')

    return df

# Example usage
df = map_remote_ratio(df)

# %%
# FancyBboxPatch: Visualization of the Generating Work Model Labels

# Define the employment types and their labels
left_labels = ['0', '50', '100']
right_labels = ['In-Person', 'Hybrid', 'Remote']
left_color = '#C38F9E'
right_color = '#66B2CC'

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))  # Same figure size

# Draw rounded rectangles and arrows for each label
for i, (left, right) in enumerate(zip(left_labels, right_labels)):
    # Left side rounded rectangles
    rect_left = FancyBboxPatch(
        (0, -i * 2), 3, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=left_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_left)
    ax.text(1.5, -i * 2 + 0.75, left,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Right side rounded rectangles
    rect_right = FancyBboxPatch(
        (6, -i * 2), 5, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=right_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_right)
    ax.text(8.5, -i * 2 + 0.75, right,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Draw arrows between the left and right rectangles
    ax.annotate('', xy=(5.8, -i * 2 + 0.75), xytext=(3.2, -i * 2 + 0.75),
                arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=10))

# Adjust axis limits and turn off the axis
ax.set_xlim(-1, 12)
ax.set_ylim(-6.5, 3.5)
ax.axis('off')

# Optimize layout to avoid clipping
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>3.3. Renaming Experience Level Labels</b>
# </div>

# %%
# Converts experience levels into more descriptive names and replaces them on the original column.

# Mapping experience levels to more descriptive labels.
def map_experience_level(df, original_column='experience_level', new_column='experience_level'):

    # Define the mapping dictionary
    experience_level_mapping = {
        'EN': 'Junior',
        'MI': 'Mid-Level',
        'SE': 'Senior',
        'EX': 'Expert'
    }

    # Create the new column
    df[new_column] = df[original_column].replace(experience_level_mapping)
    return df

# Example usage
df = map_experience_level(df)

# %%
# FancyBboxPatch: Visualization of the Renaming Experience Level Labels

# Define the employment types and their labels
left_labels = ['EN', 'MI', 'SE', 'EX']
right_labels = ['Junior', 'Mid-Level', 'Senior', 'Expert']
left_color = '#C38F9E'
right_color = '#66B2CC'

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))  # Same figure size

# Draw rounded rectangles and arrows for each label
for i, (left, right) in enumerate(zip(left_labels, right_labels)):
    # Left side rounded rectangles
    rect_left = FancyBboxPatch(
        (0, -i * 2), 3, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=left_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_left)
    ax.text(1.5, -i * 2 + 0.75, left,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Right side rounded rectangles
    rect_right = FancyBboxPatch(
        (6, -i * 2), 5, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=right_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_right)
    ax.text(8.5, -i * 2 + 0.75, right,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Draw arrows between the left and right rectangles
    ax.annotate('', xy=(5.8, -i * 2 + 0.75), xytext=(3.2, -i * 2 + 0.75),
                arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=10))

# Adjust axis limits and turn off the axis
ax.set_xlim(-1, 12)  # Same x-axis limit
ax.set_ylim(-7.5, 2.5)  # Same y-axis limit
ax.axis('off')  # Hide the axis

# Optimize layout to avoid clipping
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>3.4. Renaming Employment Type Labels</b>
# </div>

# %%
# Converts employment types into more descriptive names and replaces them on the original column.

# Mapping employment types to more descriptive labels.
def map_employment_type(df, original_column='employment_type', new_column='employment_type'):

    # Define the mapping dictionary
    employment_type_mapping = {
        'FT': 'Full-Time',
        'PT': 'Part-Time',
        'CT': 'Contract',
        'FL': 'Freelance'
    }

    # Apply the mapping with a default value of 'Other' for unmapped codes
    df[new_column] = df[original_column].map(employment_type_mapping).fillna('Other')

    return df

# Example usage
df = map_employment_type(df)

# %%
# FancyBboxPatch: Visualization of the Renaming Employment Type Labels

# Define the employment types and their labels
left_labels = ['FT', 'PT', 'CT', 'FL']
right_labels = ['Full-Time', 'Part-Time', 'Contract', 'Freelance']
left_color = '#C38F9E'
right_color = '#66B2CC'

# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))  # Same figure size

# Draw rounded rectangles and arrows for each label
for i, (left, right) in enumerate(zip(left_labels, right_labels)):
    # Left side rounded rectangles
    rect_left = FancyBboxPatch(
        (0, -i * 2), 3, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=left_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_left)
    ax.text(1.5, -i * 2 + 0.75, left,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Right side rounded rectangles
    rect_right = FancyBboxPatch(
        (6, -i * 2), 5, 1.5,  # Position and size
        boxstyle="round,pad=0.0,rounding_size=0.3",  # Rounded corners
        color=right_color, ec='black', lw=1.5  # Fill color and border
    )
    ax.add_patch(rect_right)
    ax.text(8.5, -i * 2 + 0.75, right,  # Text position
            va='center', ha='center', fontsize=16, color='white', weight='bold')

    # Draw arrows between the left and right rectangles
    ax.annotate('', xy=(5.8, -i * 2 + 0.75), xytext=(3.2, -i * 2 + 0.75),
                arrowprops=dict(facecolor='black', shrink=0.05, width=1.5, headwidth=10))

# Adjust axis limits and turn off the axis
ax.set_xlim(-1, 12)  # Same x-axis limit
ax.set_ylim(-7.5, 2.5)  # Same y-axis limit
ax.axis('off')  # Hide the axis

# Optimize layout to avoid clipping
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>3.5. Checking Columns for Inconsistent & Invalid Values</b>
# </div>

# %%
# Employment Type Value Check

# Get the frequencies of the 'employment_type' column
employment_type_counts = df['employment_type'].value_counts()

# Convert the stylized table into a DataFrame
employment_type_counts_df = employment_type_counts.reset_index()
employment_type_counts_df.columns = ['Employment Type', 'Count']

# Stylize the table with larger size
employment_type_counts_df.style.set_properties(**{
    'font-size': '14pt',  # Increasing the font size
    'text-align': 'center',  # Center-aligning the text
    'padding': '8px'  # Adding padding to increase cell size
}).set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '16pt'), ('text-align', 'center'), ('padding', '8px')]}]  
    # Styling for the header
).background_gradient(cmap='YlGnBu')  # Background color
# Out:
# <style type="text/css">
# #T_9b387 th {
#   font-size: 16pt;
#   text-align: center;
#   padding: 8px;
# }
# #T_9b387_row0_col0, #T_9b387_row1_col0, #T_9b387_row2_col0, #T_9b387_row3_col0 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
# }
# #T_9b387_row0_col1 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_9b387_row1_col1, #T_9b387_row2_col1, #T_9b387_row3_col1 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
#   background-color: #ffffd9;
#   color: #000000;
# }
# </style>
# <table id="T_9b387">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b387_level0_col0" class="col_heading level0 col0" >Employment Type</th>
#       <th id="T_9b387_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b387_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
# Salary Currency Value Check

# Check if the 'salary_currency' column contains unwanted unique values
salary_currency_counts = df['salary_currency'].value_counts()

# Convert the stylized table into a DataFrame
salary_currency_counts_df = salary_currency_counts.reset_index()

salary_currency_counts_df.columns = ['Salary Currency', 'Count']

salary_currency_counts_df.style.set_properties(**{
    'font-size': '14pt',  # Increasing the font size
    'text-align': 'center',  # Center-aligning the text
    'padding': '8px'  # Adding padding to increase cell size
}).set_table_styles(
    [{'selector': 'th', 'props': [('font-size', '16pt'), ('text-align', 'center'), ('padding', '8px')]}]  
    # Styling for the header
).background_gradient(cmap='YlGnBu')  # Background color
# Out:
# <style type="text/css">
# #T_1cbac th {
#   font-size: 16pt;
#   text-align: center;
#   padding: 8px;
# }
# #T_1cbac_row0_col0, #T_1cbac_row1_col0, #T_1cbac_row2_col0, #T_1cbac_row3_col0, #T_1cbac_row4_col0, #T_1cbac_row5_col0, #T_1cbac_row6_col0, #T_1cbac_row7_col0, #T_1cbac_row8_col0, #T_1cbac_row9_col0, #T_1cbac_row10_col0, #T_1cbac_row11_col0, #T_1cbac_row12_col0, #T_1cbac_row13_col0, #T_1cbac_row14_col0, #T_1cbac_row15_col0, #T_1cbac_row16_col0, #T_1cbac_row17_col0, #T_1cbac_row18_col0, #T_1cbac_row19_col0, #T_1cbac_row20_col0, #T_1cbac_row21_col0, #T_1cbac_row22_col0 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
# }
# #T_1cbac_row0_col1 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_1cbac_row1_col1 {
#   font-size: 14pt;
#   text-align: center;
#   padding: 8px;
#   background-color: #f9fdcc;
#   color: #000000;
# }
# #T_1cbac_row2_col1 {
#   font-size: 14pt;
# ...

# %%
# Pie Chart: Salary Negative Value Check (Proportion of Salaries <=0 vs >0)

# Calculate the number of records where salary <= 0 and where salary > 0
salary_count_leq_0 = (df['salary'] <= 0).sum()
salary_count_gt_0 = (df['salary'] > 0).sum()

# Prepare the data
data = [salary_count_leq_0, salary_count_gt_0]
labels = ['Salary <= 0', 'Salary > 0']

# Create the pie chart
plt.figure(figsize=(8, 8))  # Set figure size
wedges, texts, autotexts = plt.pie(
    data, labels=labels, autopct='%1.1f%%', startangle=90, 
    colors=['red', 'darkgreen'], wedgeprops={'edgecolor': 'black'}
)

# Add a legend
plt.legend(wedges, labels, title="Salary Status", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Add a title
plt.title('Proportion of Salaries (<= 0) vs (> 0)')

# Display the chart
plt.show()

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 4: Detecting and Handling Outliers</b>
# </div>

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>4.1. Detecting Outliers</b>
# </div>

# %%
# BoxPlot & DistPlot Chart: Outliers Control

# Data preparation
hist_data = [df['salary_in_usd']]
group_labels = ['Salary in USD']

# Create Box Plot
fig1 = px.box(
    y=df['salary_in_usd'],
    template='plotly_dark',
    title='Salary (BoxPlot)'
)

# Create DistPlot (Distribution Plot)
fig2 = ff.create_distplot(
    hist_data,
    group_labels,
    show_hist=False  # Histogram disabled
)

# Create Subplot: 1 row, 2 columns
fig = make_subplots(
    rows=1, cols=2,  # 1 row, 2 columns
    subplot_titles=('Salary (BoxPlot)', 'Salary (DistPlot)')  # Subplot titles
)

# Add Box Plot to the subplot
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

# Add DistPlot to the subplot
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# General layout settings
fig.update_layout(
    width=1000, height=500,  # Width and height
    template='plotly_dark',  # Dark theme
    font=dict(size=17, family='Franklin Gothic'),  # Font settings
    showlegend=False  # Disable legend
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>4.2. Handling Outliers</b>
# </div>

# %%
# Finding Q1, Q2, Q3 and calculating IQR, MIN, MAX

Q1=df["salary_in_usd"].quantile(0.25)
Q2=df["salary_in_usd"].quantile(0.50)
Q3=df["salary_in_usd"].quantile(0.75)
print(f"Q1={Q1}, Q2={Q2}, Q3={Q3}\n")

IQR = Q3 - Q1
print(f"IQR={IQR}\n")

lower_bound = Q1-(1.5 * IQR)
upper_bound = Q3+(1.5 * IQR)
print(f"MIN={lower_bound}, MAX={upper_bound}")
# Out:
# Q1=102000.0, Q2=141300.0, Q3=185900.0
#
# IQR=83900.0
#
# MIN=-23850.0, MAX=311750.0

# %%
# Detecting Outliers

salary_data = df['salary_in_usd']
outliers = salary_data[(salary_data < lower_bound) | (salary_data > upper_bound)]
outliers_count = len(outliers)
print(f"Number of Outliers: {outliers_count}")
#print(f"Number of Outliers: {outliers_count}, \nOutliers: \n{outliers}")
# Out:
# Number of Outliers: 270

# %%
# Deleting Outliers

df = df[~df['salary_in_usd'].isin(outliers)]

print("Outliers Deleted.")
# Out:
# Outliers Deleted.

# %%
# Boxplot & DistPlot Chart: Outliers Control Graphics (After Handling Outliers)

# Data preparation
hist_data = [df['salary_in_usd']]
group_labels = ['Salary in USD']

# Create Box Plot
fig1 = px.box(
    y=df['salary_in_usd'],
    template='plotly_dark',
    title='Salary (BoxPlot)'
)

# Create DistPlot (Distribution Plot)
fig2 = ff.create_distplot(
    hist_data,
    group_labels,
    show_hist=False  # Histogram disabled
)

# Create Subplot: 1 row, 2 columns
fig = make_subplots(
    rows=1, cols=2,  # 1 row, 2 columns
    subplot_titles=('Salary (BoxPlot)', 'Salary (DistPlot)')  # Subplot titles
)

# Add Box Plot to the subplot
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

# Add DistPlot to the subplot
for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

# General layout settings
fig.update_layout(
    width=1000, height=500,  # Width and height
    template='plotly_dark',  # Dark theme
    font=dict(size=17, family='Franklin Gothic'),  # Font settings
    showlegend=False  # Disable legend
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 5: Data Visualization</b>
# </div>

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.1. Salary Distribution by Various Factors</b>
# </div>

# %%
# Violin & Boxplot Chart: Salary Distribution by Various Factors

# Data and settings for the charts
fig1 = px.violin(
    df,
    x='work_model',
    y='salary_in_usd',
    title='Salary Distribution by Work Model',
    template='plotly_dark',
    box=True
)

fig2 = px.violin(
    df,
    x='job_category',
    y='salary_in_usd',
    title='Salary Distribution by Job Category',
    template='plotly_dark',
    box=True
)

fig3 = px.box(
    df,
    x='experience_level',
    y='salary_in_usd',
    title='Salary Distribution by Experience Level',
    template='plotly_dark'
)

fig4 = px.box(
    df,
    x='company_size',
    y='salary_in_usd',
    title='Salary Distribution by Company Size',
    template='plotly_dark'
)

# Create subplot
fig = make_subplots(
    rows=2, cols=2,  # 2 rows, 2 columns
    subplot_titles=('Work Model', 'Job Category', 'Experience Level', 'Company Size'),  # Subplot titles
    shared_yaxes=True  # Share Y axis
)

# Add each violin plot to the subplot
fig.add_trace(fig1.data[0], row=1, col=1)
fig.add_trace(fig2.data[0], row=1, col=2)
fig.add_trace(fig3.data[0], row=2, col=1)
fig.add_trace(fig4.data[0], row=2, col=2)

# General layout settings
fig.update_layout(
    title='Salary Distribution by Various Factors',
    width=1000, height=800,  # Width and height
    font=dict(size=17, family='Franklin Gothic'),  # Font settings
    showlegend=False,  # Disable legend
    template='plotly_dark',  # Dark theme
    plot_bgcolor='#000000',  # Background color of the chart (dark gray)
    paper_bgcolor='#000000',  # Background color of the page (dark gray)
    margin=dict(l=50, r=50, t=70, b=50)  # Margins
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.2. Salary & Job Postings Trends Overtime</b>
# </div>

# %%
# Line Chart: Overview - Salary & Job Postings Trends Overtime

# 1st Chart: Salary Trends Over Time
salary_trends = df.groupby(['work_year'])['salary_in_usd'].mean().reset_index()
fig1 = px.line(
    salary_trends, x='work_year', y='salary_in_usd',
    title='Salary Trends Over Time',
    markers=True, template='plotly_dark'
)

fig1.update_xaxes(tickvals=salary_trends['work_year'].unique(), tickformat='%Y')

# 2nd Chart: Salary Trends Over Time by Job Category
salary_trends_by_category = df.groupby(['work_year', 'job_category'])['salary_in_usd'].mean().reset_index()
fig2 = px.line(
    salary_trends_by_category, x='work_year', y='salary_in_usd',
    color='job_category', title='Salary Trends Over Time by Job Category',
    markers=True, template='plotly_dark'
)

fig2.update_xaxes(tickvals=salary_trends_by_category['work_year'].unique(), tickformat='%Y')

# 3rd Chart: Job Postings Over Time
job_postings_over_time = df.groupby(['work_year'])['job_category'].count().reset_index(name='count')
fig3 = px.line(
    job_postings_over_time, x='work_year', y='count',
    title='Job Postings Over Time',
    markers=True, template='plotly_dark'
)

fig3.update_xaxes(tickvals=job_postings_over_time['work_year'].unique(), tickformat='%Y')

# 4th Chart: Job Postings Over Time by Job Category
job_postings_by_category = df.groupby(['work_year', 'job_category']).size().reset_index(name='count')
fig4 = px.line(
    job_postings_by_category, x='work_year', y='count',
    color='job_category', title='Job Postings Over Time by Job Category',
    markers=True, template='plotly_dark'
)

fig4.update_xaxes(tickvals=job_postings_by_category['work_year'].unique(), tickformat='%Y')

# Create Subplot: 2 rows, 2 columns
fig = make_subplots(
    rows=2, cols=2,  # 2 rows, 2 columns
    subplot_titles=(
        'Salary Trends Over Time', 'Salary Trends by Job Category',
        'Job Postings Over Time', 'Job Postings by Job Category'
    ),  # Subplot titles
    shared_xaxes=True,  # Share X axes
    shared_yaxes=False  # Do not share Y axes
)

# Add chart data to the subplots
for trace in fig1.data:
    fig.add_trace(trace, row=1, col=1)

for trace in fig2.data:
    fig.add_trace(trace, row=1, col=2)

for trace in fig3.data:
    fig.add_trace(trace, row=2, col=1)

for trace in fig4.data:
    fig.add_trace(trace, row=2, col=2)

# General layout settings
fig.update_layout(
    title='Overview: Salary and Job Postings Trends',  # Main title
    width=1000, height=800,  # Width and height
    legend_title_text=None,  # Disable individual legend titles for each chart
    font=dict(size=17, family='Franklin Gothic'),  # General font settings
    template='plotly_dark',  # Dark theme
    plot_bgcolor='#000000', paper_bgcolor='#000000',  # Set plot and paper background to black
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.3. Salary Trends Over Time with ARIMA Forecast</b>
# </div>

# %%
# Line Chart: Salary Trends Over Time with ARIMA Forecast (2025-2029)

# Group average salaries
salary_trends = df.groupby('work_year')['salary_in_usd'].mean().reset_index()

# Convert to time series
salary_trends['work_year'] = pd.to_datetime(salary_trends['work_year'].astype(str))

# Create and train the ARIMA model
model = sm.tsa.ARIMA(salary_trends['salary_in_usd'], order=(1, 1, 1))  # You can adjust (p, d, q) parameters
model_fit = model.fit()

# Make a forecast for the next 5 years
forecast = model_fit.forecast(steps=5)

# Create a future date range for the forecast
future_years = pd.date_range(start='2024-01-01', periods=5, freq='Y')
forecast_df = pd.DataFrame({
    'work_year': future_years,
    'salary_in_usd': forecast
})

# Combine historical data with forecast data
combined_df = pd.concat([salary_trends, forecast_df])

# Create the line chart
fig = go.Figure()

# Add historical data
fig.add_trace(
    go.Scatter(
        x=salary_trends['work_year'], 
        y=salary_trends['salary_in_usd'], 
        mode='lines+markers', 
        name='Historical Salary'
    )
)

# Add forecast data
fig.add_trace(
    go.Scatter(
        x=forecast_df['work_year'], 
        y=forecast_df['salary_in_usd'], 
        mode='lines+markers', 
        name='Forecasted Salary',
        line=dict(dash='dash')  # Dashed line for forecast
    )
)

# Chart settings
fig.update_layout(
    title='Salary Trends Over Time with ARIMA Forecast (2025-2029)',
    xaxis_title='Year',
    yaxis_title='Average Salary (USD)',
    template='plotly_dark',
    font=dict(size=17, family='Franklin Gothic'),
    width=1000, height=600,  # Width and height
)

# X-axis settings: Display years properly with rotation
fig.update_xaxes(
    tickformat='%Y',  # Display in year format
    dtick='M12',  # Add a tick every 12 months (yearly)
    tickangle=45  # Rotate x-axis labels 45 degrees
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.4. Correlation Between Salary & Employee Residence & Company Location</b>
# </div>

# %%
# HeatMap Chart: Correlation Between Salary & Employee Residence & Company Location

# Convert categorical columns to numerical
le = LabelEncoder()
df['employee_residence_encoded'] = le.fit_transform(df['employee_residence'])
df['company_location_encoded'] = le.fit_transform(df['company_location'])

# Calculate the correlation matrix
correlation_matrix = df[['salary_in_usd', 'employee_residence_encoded', 'company_location_encoded']].corr()
xtick_labels = ['Salary', 'Employee Residence', 'Company Location']
ytick_labels = ['Salary', 'Employee Residence', 'Company Location']

# Create HeatMap
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix, 
    annot=True, 
    cmap='YlGnBu', 
    cbar_kws={'label': 'Correlation Coefficient'},
    xticklabels=xtick_labels,
    yticklabels=ytick_labels
)

# Write x-axis labels horizontally
plt.xticks(fontsize=14, rotation=0, ha='center')

# Leave y-axis labels vertical
plt.yticks(fontsize=14, rotation=90)

# Add title
plt.title('Salary & Employee Residence & Company Location Correlation', fontsize=20, pad=30, loc='center')

# Adjust layout
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.5. Job Postings Comparison by Job Category</b>
# </div>

# %%
# Bar Chart: Job Postings by Job Category (Colored by Salary)

# Prepare the data: Group by job category and calculate the number of postings and average salary
job_postings_and_salary = (
    df.groupby('job_category')
    .agg(
        job_posting_count=('job_category', 'size'),  # Number of job postings
        avg_salary=('salary_in_usd', 'mean')  # Average salary
    )
    .reset_index()
)

# Create the bar chart
fig = px.bar(
    job_postings_and_salary,
    x='job_posting_count',  # X-axis: Number of postings
    y='job_category',  # Y-axis: Job category
    color='avg_salary',  # Color: Based on average salary
    color_continuous_scale='Blues',  # Blue color palette
    title='Job Postings Comparison by Job Category (Colored by Salary)',  # Chart title
    text='job_posting_count',  # Display the number of postings on the bars
    width=1000, height=600,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Layout settings: Background and axis titles
fig.update_layout(
    xaxis_title='Job Count',  # X-axis title
    yaxis_title='Job Category',  # Y-axis title
    title={'x': 0.5, 'font_size': 24}  # Center align the title and set font size
)

# Adjust text size and position on bars
fig.update_traces(
    texttemplate='%{text}',  # Display text above the bars
    textposition='outside',  # Place the text outside the bars
    textfont_size=14  # Set the font size of the text
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.6. Job Postings Comparison by Employment Type & Experience Level</b>
# </div>

# %%
# Sunburst Chart: Job Postings Comparison by Employment Type & Experience Level (Colored by Salary)

# Data preparation: Calculate the number of postings and average salary by Employment Type and Experience Level
job_postings_with_salary = (
    df.groupby(['employment_type', 'experience_level'])
    .agg(
        job_posting_count=('employment_type', 'size'),  # Number of job postings
        avg_salary=('salary_in_usd', 'mean')  # Average salary
    )
    .reset_index()
)

# Create the Sunburst chart
fig = px.sunburst(
    job_postings_with_salary,
    path=['employment_type', 'experience_level'],  # Hierarchy: Employment Type -> Experience Level
    values='job_posting_count',  # Slice size: Number of job postings
    color='avg_salary',  # Color: Based on average salary
    color_continuous_scale='Blues',  # Blue color palette
    title='Job Postings Comparison by Employment Type & Experience Level',  # Chart title
    labels={
        'job_posting_count': 'Number of Job Postings',
        'avg_salary': 'Average Salary (USD)'
    },
    width=800, height=800,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Layout settings: Background and axis titles
fig.update_layout(
    title={'x': 0.5, 'font_size': 24},  # Center align title and set font size
)

# Add custom data for number of postings and average salary with percentages in the hover tooltip
fig.update_traces(
    textinfo='label+text+percent entry',  # Display label, text, and percentage
    customdata=job_postings_with_salary[['job_posting_count', 'avg_salary']],  # Custom data: Postings and salary
    hovertemplate=(
        '<b>%{label}</b><br>'
        'Number of Postings: %{customdata[0]}<br>'
        'Average Salary (USD): %{customdata[1]:.2f}'
    )
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.7. Full-Time Employment Comparison by Work Model</b>
# </div>

# %%
# Bar Chart: Full-Time Employment Comparison by Work Model

# Prepare data: Filter only 'full-time' employment type and group by job category and work model
job_data_full_time = (
    df[df['employment_type'] == 'Full-Time']
    .groupby(['job_category', 'work_model'])
    .size()
    .reset_index(name='count')
)

# Create the clustered bar chart
fig = px.bar(
    job_data_full_time, 
    x='job_category',  # X-axis: Job Category
    y='count',  # Y-axis: Count of Jobs
    color='work_model',  # Color based on Work Model
    barmode='group',  # Group bars for better comparison
    title='Full-Time Employment Comparison by Work Model',  # Chart title
    labels={'count': 'Number of Jobs', 'job_category': 'Job Category'},  # Axis labels
    width=1000, height=800,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Update layout for better spacing and alignment
fig.update_layout(
    title=dict(x=0.5, font_size=24),  # Center title
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    legend_title='Work Model',  # Legend title
    margin=dict(l=50, r=50, t=50, b=100)  # Adjust margins
)

# Display job counts on top of the bars
fig.update_traces(
    texttemplate='%{y}',  # Display the Y value (job count)
    textposition='outside',  # Place text outside the bars
    textfont_size=14  # Set text font size
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.8. Average Salary & Work Model Comparison by Job Postings (Strip Plot)</b>
# </div>

# %%
# Strip Plot: Average Salary & Work Model Comparison by Job Postings

# Prepare the data: Expand job postings to represent individual points
expanded_data = df[['work_model', 'salary_in_usd']]  # Use only necessary columns

# Create the strip plot
fig = px.strip(
    expanded_data, 
    x='work_model',  # X-axis: Work Model
    y='salary_in_usd',  # Y-axis: Salary (one point per job posting)
    color='work_model',  # Different colors for each work model
    title='Average Salary by Work Model (One Point per Job Posting)',  # Chart title
    labels={
        'salary_in_usd': 'Salary (USD)', 
        'work_model': 'Work Model'
    },  # Axis labels
    template='plotly_dark',  # Dark theme
    width=1000, height=1000,  # Width and height
)

# Adjust layout for better readability
fig.update_layout(
    title=dict(x=0.5, font_size=24),  # Center the title
    xaxis_tickangle=-45,  # Rotate x-axis labels for better readability
    legend_title='Work Model',  # Legend title
    margin=dict(l=50, r=50, t=50, b=100)  # Adjust margins
)

# Reduce the size of the points and their opacity
fig.update_traces(
    marker=dict(size=3, opacity=0.6)  # Set point size to 6 and opacity to 0.6
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.9. Average Salary & Work Model Comparison by Job Postings (Density Heatmap)</b>
# </div>

# %%
# Density Heatmap: Average Salary & Work Model Comparison by Job Postings

# Create the Density Heatmap
fig = px.density_heatmap(
    df, 
    x='work_model',  # X-axis: Work Model
    y='salary_in_usd',  # Y-axis: Salary (USD)
    title='Salary by Work Model (Colored by Job Postings)',  # Chart title
    labels={'salary_in_usd': 'Salary (USD)', 'work_model': 'Work Model'},  # Axis labels
    color_continuous_scale='Blues',  # Color palette
    width=800, height=600  # Width and height
)

# X-axis and Y-axis settings (to avoid repetition)
fig.update_xaxes(
    title_font=dict(size=16, family='Franklin Gothic'),  # X-axis title font
    tickangle=0,  # X-axis label angle
    tickfont=dict(size=18)  # X-axis tick label size
)

fig.update_yaxes(
    title_font=dict(size=16, family='Franklin Gothic'),  # Y-axis title font
    tickangle=0,  # Y-axis label angle
    tickfont=dict(size=16)  # Y-axis tick label size
)

# Layout (Design) and background settings
fig.update_layout(
    template='plotly_dark',  # Plotly Dark theme
    font=dict(size=16, family='Franklin Gothic'),  # General font settings
    title=dict(
        text='Salary by Work Model (Colored by Job Postings)',  # Title text
        font=dict(size=24),  # Title font
        x=0.5,  # Center the title horizontally
        xanchor='center',  # Anchor the title at the center
        pad=dict(t=20, b=20)  # Title padding (top-bottom)
    ),
    margin=dict(l=50, r=50, t=50, b=50)  # Chart margins
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.10. Job Postings Comparison by Company Size</b>
# </div>

# %%
# Pie Chart: Job Postings Comparison by Company Size (Colored by Salary)

# Data preparation: Calculate the number of postings and average salary by Company Size
job_postings_and_salary = (
    df.groupby('company_size')
    .agg(
        job_posting_count=('company_size', 'size'),  # Number of job postings
        avg_salary=('salary_in_usd', 'mean')  # Average salary
    )
    .reset_index()
)

# Calculate percentage of job postings
total_postings = job_postings_and_salary['job_posting_count'].sum()
job_postings_and_salary['percentage'] = (
    job_postings_and_salary['job_posting_count'] / total_postings * 100
).round(2)  # Rounded to two decimal places

# Create the Sunburst chart
fig = px.sunburst(
    job_postings_and_salary,
    path=['company_size'],  # Hierarchy: Only company_size
    values='job_posting_count',  # Slice size: Number of job postings
    color='avg_salary',  # Color: Based on average salary
    color_continuous_scale='Blues',  # Blue color palette
    title='Job Postings by Company Size (Colored by Salary)',  # Chart title
    labels={
        'job_posting_count': 'Number of Job Postings',
        'avg_salary': 'Average Salary (USD)'
    },
    width=800, height=800,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Layout settings: Center the title and adjust font size
fig.update_layout(
    title={'x': 0.5, 'font_size': 24},  # Center title and set font size
)

# Add custom data to display number of postings and percentage in each slice
fig.update_traces(
    textinfo='label+text+percent entry',  # Display label, count, and percentage
    customdata=job_postings_and_salary[['job_posting_count', 'percentage']],  # Custom data: Postings and percentage
    hovertemplate=(
        '<b>%{label}</b><br>'  # Hover label
        'Number of Postings: %{customdata[0]}<br>'  # Display number of postings
        'Percentage: %{customdata[1]}%'  # Display percentage
    )
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.11. Average Salary Comparison by Company Size & Job Category</b>
# </div>

# %%
# Bar Chart: Average Salary Comparison by Company Size & Job Category

# Grouping by company_size, job_category, and salary_in_usd to calculate average salary
df_grouped = df.groupby(['company_size', 'job_category'])['salary_in_usd'].mean().reset_index()

# Create the bar chart (average salaries by company_size for each job_category)
fig = px.bar(
    df_grouped, 
    x='job_category',  # X-axis: Job Category
    y='salary_in_usd',  # Y-axis: Average Salary (USD)
    color='company_size',  # Color based on Company Size
    barmode='group',  # Grouped bars side by side
    title='Average Salary Comparison by Company Size & Job Category',  # Chart title
    labels={
        'salary_in_usd': 'Average Salary (USD)', 
        'job_category': 'Job Category'
    },  # Axis labels
    template='plotly_dark',  # Dark theme
    color_discrete_sequence=['#007acc', '#4199d1', '#66b3d6', '#8ccc9d'],  # Custom color palette
    width=1000, height=800,  # Width and height
)

# Customize the layout
fig.update_layout(
    xaxis_title='Job Category',  # X-axis title
    yaxis_title='Average Salary (USD)',  # Y-axis title
    legend_title='Company Size',  # Legend title
    font=dict(size=14),  # Font size settings
    xaxis_tickangle=-45  # Rotate X-axis labels
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.12. Job Postings Comparison by Slary Currency</b>
# </div>

# %%
# Bar Chart: Job Postings Comparison by Slary Currency

# Get the top 10 salary currencies by frequency
currency_counts = df['salary_currency'].value_counts()  # Count occurrences of each currency
top10_salary_currency = currency_counts[:10]  # Select the top 10

# Create the bar chart
fig = px.bar(
    x=top10_salary_currency.index,  # Y-axis: Top 10 Salary Currencies
    y=top10_salary_currency.values,  # X-axis: Frequency (Number of Job Postings)
    color=top10_salary_currency.index,  # Color based on currency
    color_discrete_sequence=px.colors.sequential.Turbo,  # Sequential color palette
    text=top10_salary_currency.values,  # Display frequency as text on bars
    title='Top 10 Salary Currencies by Job Postings',  # Chart title
    template='plotly_dark',  # Dark theme
    width=1000, height=600,  # Width and height
)

# Update layout for better readability
fig.update_layout(
    xaxis_title='Salary Currency',  # X-axis label
    yaxis_title='Number of Job Postings',  # Y-axis label
    font=dict(size=17, family='Franklin Gothic')  # Font settings
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.13. Job Category Distribution for Top 3 Salary Currencies</b>
# </div>

# %%
# Sunburst Chart: Job Category Distribution for Top 3 Salary Currencies (Colored by Salary)

# Get the top 3 salary currencies by frequency
currency_counts = df['salary_currency'].value_counts()  # Count occurrences of each currency
top3_salary_currency = currency_counts[:3].index  # Select the top 3 currencies

# Filter the data to include only the top 3 salary currencies
filtered_data = df[df['salary_currency'].isin(top3_salary_currency)]

# Group data to calculate the number of postings and average salary
job_postings_with_salary = (
    filtered_data.groupby(['salary_currency', 'job_category'])
    .agg(
        job_posting_count=('salary_currency', 'size'),  # Number of job postings
        avg_salary=('salary_in_usd', 'mean')  # Average salary
    )
    .reset_index()
)

# Create the Sunburst chart
fig = px.sunburst(
    job_postings_with_salary,
    path=['salary_currency', 'job_category'],  # Hierarchical levels: Currency -> Job Category
    values='job_posting_count',  # Slice size: Number of job postings
    color='avg_salary',  # Color based on average salary
    color_continuous_scale='Blues',  # Blue color palette
    title='Job Category Distribution for Top 3 Salary Currencies',  # Chart title
    labels={
        'job_posting_count': 'Number of Job Postings',
        'avg_salary': 'Average Salary (USD)'
    },
    width=800, height=800,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Update layout for better readability
fig.update_layout(
    title=dict(x=0.5, font_size=24),  # Center align title
    margin=dict(l=50, r=50, t=50, b=100),  # Adjust margins
    coloraxis_colorbar=dict(title='Average Salary (USD)')  # Colorbar title
)

# Add custom data to display job postings, average salary, and percentages in the hover tooltip
fig.update_traces(
    textinfo='label+percent entry',  # Display label and percentage
    customdata=job_postings_with_salary[['job_posting_count', 'avg_salary']],  # Custom data for hover
    hovertemplate=(
        '<b>%{label}</b><br>'
        'Number of Postings: %{customdata[0]}<br>'
        'Average Salary (USD): %{customdata[1]:.2f}<br>'
        'Percentage: %{percentEntry:.2%}'  # Display percentage
    )
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.14. Work Model & Job Category Correlation by Job Postings</b>
# </div>

# %%
# Heatmap Chart: Work Model & Job Category Correlation by Job Postings

# Prepare the data for the heatmap
job_category_by_work_model = pd.crosstab(df['work_model'], df['job_category'])

# Create the heatmap
plt.figure(figsize=(10, 6))  # Set figure size
sns.heatmap(
    job_category_by_work_model, 
    annot=True, cmap='Blues', fmt='d', linewidths=0.5
)

# Set title and labels
plt.title("Work Model & Job Category Correlation by Job Postings", fontsize=18, color='white', pad=30)
plt.xlabel("Job Category", fontsize=14, labelpad=10, color='white')
plt.ylabel("Work Model", fontsize=14, labelpad=10, color='white')

# Set tick parameters
plt.xticks(rotation=45, fontsize=12, color='white')
plt.yticks(rotation=0, fontsize=12, color='white')

# Set background color similar to Plotly Dark theme
plt.gca().set_facecolor('#000000')

# Display the chart
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.15. Employment Type & Job Category Correlation by Job Postings</b>
# </div>

# %%
# Heatmap Chart: Employment Type & Job Category Correlation by Job Postings

# Prepare the data for the heatmap
job_category_by_employment_type = pd.crosstab(df['employment_type'], df['job_category'])

# Create the heatmap
plt.figure(figsize=(10, 7.5))  # Set figure size
sns.heatmap(
    job_category_by_employment_type, 
    annot=True, cmap='Purples', fmt='d', linewidths=0.5
)

# Set title and labels
plt.title("Employment Type & Job Category Correlation by Job Postings", fontsize=18, color='white', pad=30)
plt.xlabel("Job Category", fontsize=14, labelpad=10, color='white')
plt.ylabel("Employment Type", fontsize=14, labelpad=10, color='white')

# Set tick parameters
plt.xticks(rotation=45, fontsize=12, color='white')
plt.yticks(rotation=0, fontsize=12, color='white')

# Set background color similar to Plotly Dark theme
plt.gca().set_facecolor('#000000')

# Display the chart
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.16. Job Postings by Top 10 Job Titles</b>
# </div>

# %%
# Bar Chart: Job Postings by Top 10 Job Titles

top10_job_title = df['job_title'].value_counts()[:10]

fig = px.bar(
    y=top10_job_title.values,
    x=top10_job_title.index,
    color = top10_job_title.index,
    color_discrete_sequence=px.colors.sequential.haline,
    text=top10_job_title.values,
    title= 'Job Postings by Top 10 Job Titles',
    template= 'plotly_dark',
    width=1000, height=800,  # Width and height
)

fig.update_layout(
    xaxis_title="Job Titles",
    yaxis_title="Job Postings",
    font = dict(size=17,family="Franklin Gothic"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.17. Job Postings by Top 10 Location of Employee</b>
# </div>

# %%
# Bar Chart: Job Postings by Top 10 Location of Employee

residence = df['employee_residence'].value_counts()

top10_employee_location = residence[:10]

fig = px.bar(
    y=top10_employee_location.values,
    x=top10_employee_location.index,
    color = top10_employee_location.index,
    color_discrete_sequence=px.colors.sequential.haline,
    text=top10_employee_location.values,
    title= 'Top 10 Location of Employee',
    template= 'plotly_dark',
    width=1000, height=800,  # Width and height
)

fig.update_layout(
    xaxis_title="Location of Employee",
    yaxis_title="count",
    font = dict(size=17,family="Franklin Gothic"))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.18. Salary Distribution for Different Job Categories</b>
# </div>

# %%
# Histogram Chart: Salary Distribution for Different Job Categories

# Create a Histogram with Facet columns for job category
# Create a 2x2 layout with histograms
fig = px.histogram(
    df,
    x='salary_in_usd',  # X-axis: Salary in USD
    color='job_category',  # Color based on job category
    facet_col='job_category',  # Split into columns by job category
    facet_col_wrap=2,  # Create a 2-column layout
    title='Salary Distribution for Different Job Categories',  # Chart title
    labels={'salary_in_usd': 'Salary (USD)'},  # Axis label
    width=1000, height=800,  # Width and height
    template='plotly_dark'  # Dark theme
)

# Update the layout to adjust facet titles
for annotation in fig.layout.annotations:
    annotation.text = annotation.text.split('=')[1]  # Extract only the category from "job_category=..."

# Layout and other settings
fig.update_layout(
    title=dict(text='Salary Distribution for Different Job Categories', font_size=24, x=0.5),  # Centered title
    margin=dict(l=50, r=50, t=80, b=50),  # Chart margins
    showlegend=True  # Show legend (turned off because each facet has individual colors)
)

# Display the chart
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.19. Remote Work Trends Over Years</b>
# </div>

# %%
# Area Chart: Remote Work Trends Over Years (Colored by Work Model)

# Distribution of remote category over years
remote_trend = df.groupby(['work_year', 'work_model']).size().unstack().fillna(0)

# Calculate percentage trends
remote_trend_percentage = remote_trend.div(remote_trend.sum(axis=1), axis=0) * 100

# Plot the area chart with a clean and distinct color palette
remote_trend_percentage.plot(
    kind='area', 
    stacked=True, 
    figsize=(8, 6), 
    colormap='Blues',  # Simple blue color palette
    alpha=0.8  # Transparency
)

# Axis and title settings
plt.title('Remote Work Trends Over Years', fontsize=20)
plt.xlabel('Year')
plt.ylabel('Percentage (%)')

# Display only whole years on the x-axis (remove fractional years)
years = remote_trend_percentage.index.tolist()  # Get the list of years
plt.xticks(ticks=years, labels=years)  # Display only whole years

# Adjust or remove the legend (side frame)
plt.legend(
    title='Work Model',
    loc='upper left',  # Position at the upper left
    bbox_to_anchor=(1, 1),  # Move it to the top-right corner outside the plot
    frameon=True  # Enable the legend frame
)

# Remove the chart spines (borders)
for spine in plt.gca().spines.values():
    spine.set_visible(False)

# Adjust layout for better spacing
plt.tight_layout()

# Display the chart
plt.show()

# %% [markdown]
# <div align="left" style="
#     background-color: #508E9F;
#     font-size: 25px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.0;
#     border-radius: 100px;
#     margin: 20px 0;
# ">
#     <b>5.20. Job Title Distribution by Job Postings</b>
# </div>

# %%
# WordCloud: Job Title Distribution by Job Postings

def Freq_df(cleanwordlist):
    # Create frequency distribution from the cleaned word list
    Freq_dist_nltk = nltk.FreqDist(cleanwordlist)
    df_freq = pd.DataFrame.from_dict(Freq_dist_nltk, orient='index')  # Convert to DataFrame
    df_freq.columns = ['Frequency']  # Set column name
    df_freq.index.name = 'Term'  # Set index name
    df_freq = df_freq.sort_values(by=['Frequency'], ascending=False)  # Sort by frequency
    df_freq = df_freq.reset_index()  # Reset index
    return df_freq  # Return the frequency DataFrame

def Word_Cloud(data, color_background, colormap, title):
    plt.figure(figsize=(20,10))  # Set figure size
    wc = WordCloud(
        width=1200,  # Width of the word cloud
        height=800,  # Height of the word cloud
        max_words=50,  # Maximum number of words to display
        colormap=colormap,  # Color palette for the word cloud
        max_font_size=100,  # Maximum font size
        random_state=88,  # Random seed for reproducibility
        background_color=color_background  # Background color
    ).generate_from_frequencies(data)  # Generate word cloud from frequency data
    
    plt.imshow(wc, interpolation='bilinear')  # Display the word cloud with smooth interpolation
    plt.title(title, fontsize=20)  # Set the title of the word cloud
    plt.axis('off')  # Turn off the axis
    plt.show()  # Display the plot

# Create the frequency DataFrame from job titles
freq_df = Freq_df(df['job_title'].values.tolist())
data = dict(zip(freq_df['Term'].tolist(), freq_df['Frequency'].tolist()))  # Convert to dictionary
data = freq_df.set_index('Term').to_dict()['Frequency']  # Set index to 'Term' and convert to dictionary

# Generate the word cloud
Word_Cloud(data, 'black', 'RdBu', '')  # Black background, RdBu colormap, no title

# %% [markdown]
# <div align="center" style="
#     background-color: #003366;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #F9F9F9;
#     padding: 20px;
#     line-height: 1.5;
#     border-radius: 20px;
#     margin: 20px 0;
# ">
#     <b>Step 6: Conclusion - Key Insights and Summary</b>
# </div>

# %% [markdown]
# ### 🎯 **Key Findings**
#
# - This analysis provided **valuable insights into the dynamics of data science jobs**.
#
# - By exploring **salary trends, employment types, experience levels,** and **company sizes**, we identified several key factors that influence compensation in the field.
#
# ### 📍 Remote Work and Salary
# - The ratio of **remote work** has a significant impact on salaries.
# - In certain sectors, **fully remote workers** can command **competitive salaries** compared to their in-office counterparts.
#
# ### 📍 Experience Level and Salary
# - **Experience level** plays a crucial role in salary determination.
# - **Senior** and **expert-level positions** show significantly **higher salaries**, especially in regions like the **US and Europe**.
#
# ### 📍 Company Size and Salary
# - **Larger companies** tend to offer **more competitive salaries**.
# - **Small and medium-sized companies**, however, often provide **other employment advantages** (e.g., work-life balance, career growth opportunities).
#
# <br>
#
# ### 📝 **Strategic Career Planning**
#
# These insights can help both **seasoned professionals** and **newcomers** make informed career decisions by:
# - Understanding the **impact of remote work** on compensation.
# - Benchmarking **salaries based on experience levels**.
# - Weighing the pros and cons between **different company sizes**.
#
# <br>
#
# ### 🌟 **Additional Insights from the Data Science Job Analysis**
#
# ### 📈 Salary Growth in Data Fields
# - **Salaries in the data science field** have shown consistent growth over time.
#
# ### 🔍 Trends in Job Types Over Time
# - **In-person job postings** are increasing, while **remote job opportunities** are on the decline over the years.
#
# ### 🌍 Geographical Distribution of Job Postings
# - The **highest number of job postings** are available in the **United States (US)**.
#
# ### 🌐 Weak Correlation Between Salary and Location
# - **Salaries** show **minimal correlation with geographical location**.
#
# ### 🧑‍🔬 Most Available Job Role
# - **Data Scientist** roles have the **highest job availability** and **second highest average salaries**.
#
# ### 💰 Highest Paying Role & Lowest Job Availability
# - Although **Machine Learning Engineers** have the **fewest job postings**, they command the **highest average salaries**.
#
# ### 💼 ML Engineer Salary by Company Size
# - **Machine Learning Engineer salaries** tend to be **lower in large-sized companies (L-size)** compared to smaller or medium-sized firms.
#
# ### 🕒 Full-Time Employment Dominates
# - **More than 99% of job postings** are for **full-time positions**.
#
# ### 🧑‍💼 Experience Level and Job Postings
# - **Senior-level roles** have the **highest number of job postings**, but **expert-level positions** offer the **highest average salaries**.
#
# ### 🏢 Company Size vs Average Salary & Job Postings
# - **Highest average salaries** and **92% of the job postings** come from **medium-sized (M-size) companies**.

# %% [markdown]
# <div align="center" style="
#     background-color: #4CAF50;
#     font-size: 40px;
#     font-family: 'Arial', sans-serif;
#     color: #FFFFFF;
#     padding: 25px 40px;
#     line-height: 1.5;
#     border-radius: 50px;
#     margin: 30px 0;
#     box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
# ">
#     <b>🌟 THANK YOU for reviewing my project! 🌟</b>
# </div>
